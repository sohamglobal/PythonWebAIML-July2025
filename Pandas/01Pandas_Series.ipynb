# %%
import numpy
import pandas

# %%
lst=['praffull','java',9,'python','microsoft','volkswagen',1.13]

# %%
arr=numpy.array(lst)
print(arr)
# Out:
# ['praffull' 'java' '9' 'python' 'microsoft' 'volkswagen' '1.13']

# %%
ser=pandas.Series(lst)
print(ser)
# Out:
# 0      praffull
# 1          java
# 2             9
# 3        python
# 4     microsoft
# 5    volkswagen
# 6          1.13
# dtype: object

# %%
print(ser[4])
# Out:
# microsoft

# %%
ser1=pandas.Series(arr)
print(ser1)
# Out:
# 0      praffull
# 1          java
# 2             9
# 3        python
# 4     microsoft
# 5    volkswagen
# 6          1.13
# dtype: object
