# %%
import numpy
import pandas

# %%
lst=[
    ['the matrix','pk','dil se'],
    [1999,2014,1998],
    ['action','comedy','romance'],
    ['english','hindi','tamil'],
    ['keanu reeves','amir khan','shah rukh khan'],
    [8.9,8.7,7.6]
]

# %%
arr=numpy.array(lst)
print(arr)
# Out:
# [['the matrix' 'pk' 'dil se']
#  ['1999' '2014' '1998']
#  ['action' 'comedy' 'romance']
#  ['english' 'hindi' 'tamil']
#  ['keanu reeves' 'amir khan' 'shah rukh khan']
#  ['8.9' '8.7' '7.6']]

# %%
df=pandas.DataFrame(lst)
print(df)
# Out:
#               0          1               2
# 0    the matrix         pk          dil se
# 1          1999       2014            1998
# 2        action     comedy         romance
# 3       english      hindi           tamil
# 4  keanu reeves  amir khan  shah rukh khan
# 5           8.9        8.7             7.6

# %%
rows=['filmname','releaseyear','genre','language','actor','imdbrating']
cols=['soham','praffull','sharayu']
df1=pandas.DataFrame(arr,rows,cols)
print(df1)
# Out:
#                     soham   praffull         sharayu
# filmname       the matrix         pk          dil se
# releaseyear          1999       2014            1998
# genre              action     comedy         romance
# language          english      hindi           tamil
# actor        keanu reeves  amir khan  shah rukh khan
# imdbrating            8.9        8.7             7.6

# %%
print(df1['praffull'])
# Out:
# filmname              pk
# releaseyear         2014
# genre             comedy
# language           hindi
# actor          amir khan
# imdbrating           8.7
# Name: praffull, dtype: object
