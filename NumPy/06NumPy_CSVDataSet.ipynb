# %% [markdown]
# **Store CSV dataset data into Numpy array**

# %%
import numpy

# %%
arr=numpy.genfromtxt("mentalhealth.csv",delimiter=",",dtype=None, encoding=None)
print(arr)
print(arr.shape)
# Out:
# [['Name' 'Gender' 'Age' ... 'Stress' 'Anxious' 'AcademicPerf']
#  ['Aarav' 'Male' '15' ... 'Medium' 'No' 'Same']
#  ['Meera' 'Female' '25' ... 'Medium' 'No' 'Same']
#  ...
#  ['Myra' 'Female' '15' ... 'Low' 'Yes' 'Declined']
#  ['Myra' 'Female' '20' ... 'Medium' 'No' 'Improved']
#  ['Vihaan' 'Male' '23' ... 'Low' 'No' 'Improved']]
# (1001, 10)
