# %%
import numpy

# %%
a1=numpy.array([12,23,34,45,56,67,78,89])
print(a1)
# Out:
# [12 23 34 45 56 67 78 89]

# %%
print(a1[0])
# Out:
# 12

# %%
print(a1[5])
# Out:
# 67

# %%
print(a1[2:6])
# Out:
# [34 45 56 67]

# %%
print(a1[-1])
# Out:
# 89

# %%
print(a1[::-1])
# Out:
# [89 78 67 56 45 34 23 12]

# %%
print(a1[4:])
# Out:
# [56 67 78 89]

# %%
print(a1[:5])
# Out:
# [12 23 34 45 56]

# %%
lst=[
    [12,23,34,33,77],
    [54,43,32,22,11],
    [21,76,98,76,99]
]
a2=numpy.array(lst)
print(a2)
# Out:
# [[12 23 34 33 77]
#  [54 43 32 22 11]
#  [21 76 98 76 99]]

# %%
print(a2[:,:])
# Out:
# [[12 23 34 33 77]
#  [54 43 32 22 11]
#  [21 76 98 76 99]]

# %%
print(a2[1,3])
# Out:
# 22

# %%
print(a2[1:,:])
# Out:
# [[54 43 32 22 11]
#  [21 76 98 76 99]]

# %%
print(a2[1:,1:3])
# Out:
# [[43 32]
#  [76 98]]
