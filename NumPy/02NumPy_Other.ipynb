# %%
import numpy

# %%
a1=numpy.array(['java','python','sql','spark','spring'])
print(a1)
# Out:
# ['java' 'python' 'sql' 'spark' 'spring']

# %%
a2=numpy.array([True,True,False,True,False,False,False,True])
print(a2)
# Out:
# [ True  True False  True False False False  True]

# %% [markdown]
# **All values in numpy array will be of same datatype**

# %%
a3=numpy.array([9,'praffull',68.14,False])
print(a3)
# Out:
# ['9' 'praffull' '68.14' 'False']

# %% [markdown]
# **numpy array of dates**

# %%
darr=numpy.arange('2025-06-09','2025-06-27',dtype='datetime64[D]')
print(darr)
# Out:
# ['2025-06-09' '2025-06-10' '2025-06-11' '2025-06-12' '2025-06-13'
#  '2025-06-14' '2025-06-15' '2025-06-16' '2025-06-17' '2025-06-18'
#  '2025-06-19' '2025-06-20' '2025-06-21' '2025-06-22' '2025-06-23'
#  '2025-06-24' '2025-06-25' '2025-06-26']
